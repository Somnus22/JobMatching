# %%
import re
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from transformers import AutoTokenizer, AutoModelForTokenClassification, TrainingArguments, Trainer
from datasets import Dataset
from sklearn.metrics import precision_recall_fscore_support

# %%
# Load the datasets

job_postings_df = pd.read_csv('../datasets/job_postings/computing_desc_job_posting.csv')  # Adjust filename as needed



print("\nJob postings dataset structure:")
print(job_postings_df.head())
print(job_postings_df.columns)
# Out:
# Job postings dataset structure:
#       job_id        company_name                        title  \
# 0   11009123   PGAV Destinations            project architect
# 1   69333422     Staffing Theory    product marketing manager
# 2  133130219                 NaN            software engineer
# 3  175485704                GOYT            software engineer
# 4  266825034  Recruitment Design  software support specialist
#
#                                          description  max_salary pay_period  \
# 0  PGAV Destinations is seeking a self-motivated ...         NaN        NaN
# 1  A leading pharmaceutical company committed to ...         NaN        NaN
# 2  Education Bachelor's degree in software, math,...         NaN        NaN
# 3  Job Description:GOYT is seeking a skilled and ...         NaN        NaN
# 4  Are you driven by the thrill of solving proble...     65000.0     YEARLY
#
#                         location  company_id  views  med_salary  ...  \
# 0                   St Louis, MO     93456.0    2.0         NaN  ...
# 1                  United States  27097933.0    2.0         NaN  ...
# 2  Los Angeles Metropolitan Area         NaN    1.0         NaN  ...
# 3                     Denver, CO  76987056.0  273.0         NaN  ...
# 4                     McLean, VA  99212509.0    NaN         NaN  ...
#
#    work_type currency  compensation_type  normalized_salary  zip_code  \
# 0  FULL_TIME      NaN                NaN                NaN   63367.0
# 1  FULL_TIME      NaN                NaN                NaN       NaN
# 2  FULL_TIME      NaN                NaN                NaN       NaN
# 3  PART_TIME      NaN                NaN                NaN   80202.0
# 4  FULL_TIME      USD        BASE_SALARY            62500.0   22101.0
#
#       fips    matched_category standardized_salary  description_length  \
# 0  29183.0  software architect                 0.0                 253
# 1      NaN     product manager                 0.0                 277
# 2      NaN   software engineer                 0.0                  23
# 3   8031.0   software engineer                 0.0                 223
# 4  51059.0   software engineer             65000.0                 177
#
#                                  cleaned_description
# 0  pgav destination seeking highly creative indiv...
# 1  leading pharmaceutical company committed devel...
# 2  education bachelor degree software math scienc...
# 3  job description goyt seeking skilled motivated...
# 4  driven thrill solving problem offering unparal...
#
# [5 rows x 35 columns]
# Index(['job_id', 'company_name', 'title', 'description', 'max_salary',
#        'pay_period', 'location', 'company_id', 'views', 'med_salary',
#        'min_salary', 'formatted_work_type', 'applies', 'original_listed_time',
#        'remote_allowed', 'job_posting_url', 'application_url',
#        'application_type', 'expiry', 'closed_time',
#        'formatted_experience_level', 'skills_desc', 'listed_time',
#        'posting_domain', 'sponsored', 'work_type', 'currency',
#        'compensation_type', 'normalized_salary', 'zip_code', 'fips',
#        'matched_category', 'standardized_salary', 'description_length',
#        'cleaned_description'],
#       dtype='object')

# %%
# Load the datasets

resume_df = pd.read_csv('combined_resume_data.csv')  # Adjust filename as needed



print("\nResume dataset structure:")
print(resume_df.head())
print(resume_df.columns)
# Out:
# Resume dataset structure:
#                                             raw_text                    role  \
# 0  C:\Workspace\java\scrape_indeed\dba_part_1\1.h...  Database Administrator
# 1  C:\Workspace\java\scrape_indeed\dba_part_1\10....  Database Administrator
# 2  C:\Workspace\java\scrape_indeed\dba_part_1\100...  Database Administrator
# 3  C:\Workspace\java\scrape_indeed\dba_part_1\100...  Database Administrator
# 4  C:\Workspace\java\scrape_indeed\dba_part_1\100...  Database Administrator
#
#                                           clean_text  \
# 0  database administrator database administrator ...
# 1  database administrator sql microsoft powerpoin...
# 2  oracle database administrator oracle database ...
# 3  amazon redshift administrator and etl develope...
# 4  scrum master oracle database administrator scr...
#
#                   source_file
# 0  Database_Administrator.csv
# 1  Database_Administrator.csv
# 2  Database_Administrator.csv
# 3  Database_Administrator.csv
# 4  Database_Administrator.csv
# Index(['raw_text', 'role', 'clean_text', 'source_file'], dtype='object')

# %%
# Add resume_id as primary key
resume_df.reset_index(inplace=True)
resume_df.rename(columns={'index': 'resume_id'}, inplace=True)

# %%
ENTITY_TYPES = [
    "PL",      # Programming Language
    "FW",      # Framework
    "DB",      # Database
    "CP",      # Cloud Platform
    "DO",      # DevOps
    "NS",      # Network & Security
    "DAS",     # Data Analysis & Science
    "SWE",     # Software Engineering
    "PM",      # Project Management
    "EC",      # Education Certification
    "SS"       # Soft Skills
]

# %%
keyword_mappings = {
        "PL": ["python", "java", "javascript", "c++", "c#", "go", "rust", "php", "ruby", "swift", 
               "typescript", "kotlin", "scala", "perl", "bash", "powershell", "r", "matlab", "dart", "lua"],
        
        "FW": ["react", "angular", "vue", "django", "flask", "spring", "laravel", "express", "symfony", 
               "bootstrap", "jquery", "rails", "asp.net", "node.js", "next.js", "flutter", "xamarin", "qt"],
        
        "DB": ["sql", "mysql", "postgresql", "mongodb", "oracle", "cassandra", "redis", "dynamodb", 
               "sqlite", "mariadb", "couchdb", "neo4j", "firebase", "elasticsearch", "snowflake", "bigtable"],
        
        "CP": ["aws", "azure", "gcp", "google cloud", "heroku", "digitalocean", "alibaba", "ibm cloud", 
               "oracle cloud", "salesforce", "s3", "ec2", "lambda", "kubernetes", "eks", "gke", "aks"],
        
        "DO": ["docker", "kubernetes", "jenkins", "gitlab", "github actions", "circleci", "terraform", 
               "ansible", "puppet", "chef", "prometheus", "grafana", "elk", "ci/cd", "devops", "sre"],
        
        "NS": ["firewall", "vpn", "encryption", "ssl", "tls", "authentication", "authorization", 
               "oauth", "jwt", "kerberos", "ldap", "penetration testing", "security", "cybersecurity"],
        
        "DAS": ["machine learning", "data mining", "pandas", "numpy", "tensorflow", "pytorch", "big data", 
                "hadoop", "spark", "tableau", "power bi", "data science", "statistics", "ai", "nlp"],
        
        "SWE": ["agile", "scrum", "object-oriented", "oop", "design patterns", "architecture", 
                "microservices", "rest api", "soap", "uml", "solid", "tdd", "bdd", "clean code"],
        
        "PM": ["jira", "confluence", "trello", "asana", "scrum master", "product owner", "kanban", 
               "project management", "pmp", "agile", "waterfall", "lean", "sprint planning"],
        
        "EC": ["bachelor", "master", "phd", "certificate", "certification", "aws certified", "cisco", 
               "comptia", "microsoft certified", "google certified", "pmp", "itil", "cisa", "cissp"],
        
        "SS": ["teamwork", "communication", "leadership", "problem-solving", "creativity", "collaboration", 
               "time management", "adaptability", "critical thinking", "interpersonal", "presentation"]
    }

# %%
def preprocess_text(text):
    """Clean and prepare text for NER"""
    if not isinstance(text, str):
        return ""
    
    # Remove extra whitespace and normalize text
    text = re.sub(r'\s+', ' ', text).strip()
    return text

def extract_entities(text, ner_pipeline):
    """Extract entities from text using BERT NER and keyword matching"""
    # Define keyword lists for each entity type
    keyword_mappings = {
        "PL": ["python", "java", "javascript", "c++", "c#", "go", "rust", "php", "ruby", "swift", 
               "typescript", "kotlin", "scala", "perl", "bash", "powershell", "r", "matlab", "dart", "lua"],
        
        "FW": ["react", "angular", "vue", "django", "flask", "spring", "laravel", "express", "symfony", 
               "bootstrap", "jquery", "rails", "asp.net", "node.js", "next.js", "flutter", "xamarin", "qt"],
        
        "DB": ["sql", "mysql", "postgresql", "mongodb", "oracle", "cassandra", "redis", "dynamodb", 
               "sqlite", "mariadb", "couchdb", "neo4j", "firebase", "elasticsearch", "snowflake", "bigtable"],
        
        "CP": ["aws", "azure", "gcp", "google cloud", "heroku", "digitalocean", "alibaba", "ibm cloud", 
               "oracle cloud", "salesforce", "s3", "ec2", "lambda", "kubernetes", "eks", "gke", "aks"],
        
        "DO": ["docker", "kubernetes", "jenkins", "gitlab", "github actions", "circleci", "terraform", 
               "ansible", "puppet", "chef", "prometheus", "grafana", "elk", "ci/cd", "devops", "sre"],
        
        "NS": ["firewall", "vpn", "encryption", "ssl", "tls", "authentication", "authorization", 
               "oauth", "jwt", "kerberos", "ldap", "penetration testing", "security", "cybersecurity"],
        
        "DAS": ["machine learning", "data mining", "pandas", "numpy", "tensorflow", "pytorch", "big data", 
                "hadoop", "spark", "tableau", "power bi", "data science", "statistics", "ai", "nlp"],
        
        "SWE": ["agile", "scrum", "object-oriented", "oop", "design patterns", "architecture", 
                "microservices", "rest api", "soap", "uml", "solid", "tdd", "bdd", "clean code"],
        
        "PM": ["jira", "confluence", "trello", "asana", "scrum master", "product owner", "kanban", 
               "project management", "pmp", "agile", "waterfall", "lean", "sprint planning"],
        
        "EC": ["bachelor", "master", "phd", "certificate", "certification", "aws certified", "cisco", 
               "comptia", "microsoft certified", "google certified", "pmp", "itil", "cisa", "cissp"],
        
        "SS": ["teamwork", "communication", "leadership", "problem-solving", "creativity", "collaboration", 
               "time management", "adaptability", "critical thinking", "interpersonal", "presentation"]
    }
    
    # Initialize results dictionary with empty lists for all entity types
    organized_entities = {entity_type: [] for entity_type in ENTITY_TYPES}
    
    # Handle empty or invalid input
    if not isinstance(text, str) or not text.strip():
        return organized_entities
    
    # Preprocess text
    processed_text = preprocess_text(text)
    if not processed_text:
        return organized_entities
    
    try:
        # Apply keyword-based extraction (simpler and more reliable for technical terms)
        lower_text = processed_text.lower()
        for category, keywords in keyword_mappings.items():
            for keyword in keywords:
                # Use word boundary check to avoid partial matches
                pattern = r'\b' + re.escape(keyword) + r'\b'
                if re.search(pattern, lower_text):
                    organized_entities[category].append(keyword)
        
        # Apply NER model for entities that might be missed by keywords
        max_length = 512  # BERT token limit
        words = processed_text.split()
        
        # Process text in chunks if needed
        if len(words) > max_length - 10:
            chunks = []
            for i in range(0, len(words), max_length - 10):
                chunks.append(" ".join(words[i:i+max_length-10]))
        else:
            chunks = [processed_text]
        
        # Process each chunk
        for chunk in chunks:
            try:
                # Get NER results
                ner_results = ner_pipeline(chunk)
                
                # Process each entity
                for entity in ner_results:
                    # Extract the entity word and group
                    word = entity.get("word", "").strip()
                    group = entity.get("entity_group", "")
                    
                    # Skip empty words
                    if not word:
                        continue
                    
                    # Map entity groups to our categories
                    if group == "MISC":
                        # For MISC entities, check which technical category they might belong to
                        word_lower = word.lower()
                        for cat, kw_list in keyword_mappings.items():
                            if any(kw in word_lower for kw in kw_list):
                                organized_entities[cat].append(word)
                                break
                        else:
                            # If no match found, default to Programming Language
                            organized_entities["PL"].append(word)
                    
                    elif group == "ORG":
                        # Organizations could be companies or cloud platforms
                        word_lower = word.lower()
                        if any(kw in word_lower for kw in keyword_mappings["CP"]):
                            organized_entities["CP"].append(word)
                    
                    elif group == "PER" and "years" in chunk.lower()[max(0, entity.get("start", 0)-20):entity.get("end", 0)+20]:
                        # People names near "years" might indicate experience
                        organized_entities["SS"].append(word)
            
            except Exception as e:
                print(f"Error in NER processing: {e}")
                # Continue with other chunks
        
        # Remove duplicates (case-insensitive)
        for entity_type in ENTITY_TYPES:
            seen = set()
            unique_list = []
            for item in organized_entities[entity_type]:
                item_lower = item.lower()
                if item_lower not in seen:
                    seen.add(item_lower)
                    unique_list.append(item)
            organized_entities[entity_type] = unique_list
            
    except Exception as e:
        print(f"Error in extract_entities: {e}")
        import traceback
        traceback.print_exc()
    
    return organized_entities

# %%
gt =  pd.read_csv("./final_merged.csv")

# %%
# Filter to only use rows marked as ground truth (GT = 1)
ground_truth_df = gt[gt['GT'] == 1]

# %%
ground_truth_df.size
# Out:
# 6643

# %%
def determine_entity_type(skill):
    """
    Maps a given skill to one of the predefined entity types.
    Returns "MISC" if no matching category is found.
    
    Parameters:
    skill (str): The skill to categorize
    
    Returns:
    str: Entity type code (PL, FW, DB, etc.) or "MISC" for unmatched skills
    """
    if not skill:
        return "MISC"
        
    skill_lower = skill.lower()
    
    keyword_mappings = {
        "PL": ["python", "java", "javascript", "c++", "c#", "go", "rust", "php", "ruby", "swift",
               "typescript", "kotlin", "scala", "perl", "bash", "powershell", "r", "matlab", "dart", "lua"],
        
        "FW": ["react", "angular", "vue", "django", "flask", "spring", "laravel", "express", "symfony",
               "bootstrap", "jquery", "rails", "asp.net", "node.js", "next.js", "flutter", "xamarin", "qt"],
        
        "DB": ["sql", "mysql", "postgresql", "mongodb", "oracle", "cassandra", "redis", "dynamodb",
               "sqlite", "mariadb", "couchdb", "neo4j", "firebase", "elasticsearch", "snowflake", "bigtable"],
        
        "CP": ["aws", "azure", "gcp", "google cloud", "heroku", "digitalocean", "alibaba", "ibm cloud",
               "oracle cloud", "salesforce", "s3", "ec2", "lambda", "kubernetes", "eks", "gke", "aks"],
        
        "DO": ["docker", "kubernetes", "jenkins", "gitlab", "github actions", "circleci", "terraform",
               "ansible", "puppet", "chef", "prometheus", "grafana", "elk", "ci/cd", "devops", "sre"],
        
        "NS": ["firewall", "vpn", "encryption", "ssl", "tls", "authentication", "authorization",
               "oauth", "jwt", "kerberos", "ldap", "penetration testing", "security", "cybersecurity"],
        
        "DAS": ["machine learning", "data mining", "pandas", "numpy", "tensorflow", "pytorch", "big data",
                "hadoop", "spark", "tableau", "power bi", "data science", "statistics", "ai", "nlp"],
        
        "SWE": ["agile", "scrum", "object-oriented", "oop", "design patterns", "architecture",
                "microservices", "rest api", "soap", "uml", "solid", "tdd", "bdd", "clean code"],
        
        "PM": ["jira", "confluence", "trello", "asana", "scrum master", "product owner", "kanban",
               "project management", "pmp", "agile", "waterfall", "lean", "sprint planning"],
        
        "EC": ["bachelor", "master", "phd", "certificate", "certification", "aws certified", "cisco",
               "comptia", "microsoft certified", "google certified", "pmp", "itil", "cisa", "cissp"],
        
        "SS": ["teamwork", "communication", "leadership", "problem-solving", "creativity", "collaboration",
               "time management", "adaptability", "critical thinking", "interpersonal", "presentation"]
    }
    
    # Check each category's keywords for matches
    for category, keywords in keyword_mappings.items():
        for keyword in keywords:
            # Check if the keyword is in the skill text (as a whole word or part of a compound word)
            if keyword in skill_lower:
                return category
    
    # If no match is found
    return "MISC"

# %%
def prepare_ner_data(df):
    data_list = []
    error_count = 0
    
    for idx, row in df.iterrows():
        try:
            # Get text, with fallback
            if 'raw_text' not in row or pd.isna(row['raw_text']):
                print(f"Warning: Missing text at index {idx}. Skipping this row.")
                continue
            
            text = str(row['raw_text'])  # Ensure text is string
            
            # Get skills list, with validation
            if 'skills' not in row:
                print(f"Warning: No 'skills' column at index {idx}. Skipping this row.")
                continue
                
            skills_list = row['skills']
            
            # Handle non-iterable skills_list (string instead of list)
            if isinstance(skills_list, str):
                # Split the comma-separated string into a list
                skills_list = [s.strip() for s in skills_list.split(',')]
                print(f"Converted string skills to list at index {idx}. Found {len(skills_list)} skills.")
            elif not isinstance(skills_list, (list, tuple, set)) or pd.isna(skills_list):
                print(f"Warning: skills_list is not iterable at index {idx}. Value: {skills_list}. Using empty list.")
                skills_list = []
            
            # Initialize annotations list
            annotations = []
            
            # For each skill, find it in the text and determine its entity type
            for skill in skills_list:
                # Skip None or NaN values
                if pd.isna(skill):
                    continue
                
                # Ensure skill is a string
                skill = str(skill)
                
                # Skip if skill is empty
                if not skill.strip():
                    continue
                
                # Escape special regex characters if present in the skill
                skill_pattern = re.escape(skill)
                
                # Find all occurrences of the skill in the text
                for match in re.finditer(r'\b' + skill_pattern + r'\b', text, re.IGNORECASE):
                    start, end = match.span()
                    skill_type = determine_entity_type(skill)
                    
                    annotations.append({
                        "start": start,
                        "end": end,
                        "label": skill_type
                    })
            
            data_list.append({
                "text": text,
                "annotations": annotations
            })
            
        except Exception as e:
            error_count += 1
            print(f"Error processing row at index {idx}: {e}")
            # Continue with next row instead of stopping
    
    print(f"Processed {len(df)} rows with {error_count} errors. Generated {len(data_list)} valid examples.")
    return data_list

# %%
train_df, val_df = train_test_split(ground_truth_df, test_size=0.2, random_state=42)

# %%
# Create data with annotations
train_data = prepare_ner_data(train_df)
val_data = prepare_ner_data(val_df)

# Verify the data structure
print(f"Training data: {len(train_data)} examples")
print(f"Validation data: {len(val_data)} examples")
if len(train_data) > 0:
    print("Sample annotation:", train_data[0]['annotations'][:2])
# Out:
# Converted string skills to list at index 34431. Found 48 skills.
# Converted string skills to list at index 11254. Found 97 skills.
# Converted string skills to list at index 22164. Found 92 skills.
# Converted string skills to list at index 10538. Found 192 skills.
# Converted string skills to list at index 4305. Found 66 skills.
# Converted string skills to list at index 3502. Found 47 skills.
# Converted string skills to list at index 28271. Found 18 skills.
# Converted string skills to list at index 30884. Found 30 skills.
# Converted string skills to list at index 3669. Found 36 skills.
# Converted string skills to list at index 34436. Found 57 skills.
# Converted string skills to list at index 29321. Found 37 skills.
# Converted string skills to list at index 34406. Found 49 skills.
# Converted string skills to list at index 13365. Found 64 skills.
# Converted string skills to list at index 188. Found 37 skills.
# Converted string skills to list at index 4206. Found 46 skills.
# Converted string skills to list at index 29883. Found 37 skills.
# Converted string skills to list at index 16844. Found 33 skills.
# Converted string skills to list at index 21840. Found 48 skills.
# Converted string skills to list at index 293. Found 31 skills.
# Converted string skills to list at index 2575. Found 41 skills.
# Converted string skills to list at index 19078. Found 49 skills.
# Converted string skills to list at index 32282. Found 56 skills.
# Converted string skills to list at index 20870. Found 67 skills.
# Converted string skills to list at index 33043. Found 17 skills.
# Converted string skills to list at index 4139. Found 36 skills.
# Converted string skills to list at index 9485. Found 75 skills.
# Converted string skills to list at index 14600. Found 47 skills.
# Converted string skills to list at index 20209. Found 28 skills.
# Converted string skills to list at index 24220. Found 121 skills.
# Converted string skills to list at index 34405. Found 90 skills.
# Converted string skills to list at index 20113. Found 43 skills.
# Converted string skills to list at index 27971. Found 72 skills.
# Converted string skills to list at index 32244. Found 31 skills.
# Converted string skills to list at index 1172. Found 118 skills.
# Converted string skills to list at index 3697. Found 51 skills.
# Converted string skills to list at index 663. Found 55 skills.
# Converted string skills to list at index 23671. Found 28 skills.
# Converted string skills to list at index 32938. Found 42 skills.
# Converted string skills to list at index 16066. Found 41 skills.
# Converted string skills to list at index 24235. Found 27 skills.
# Converted string skills to list at index 24096. Found 53 skills.
# Converted string skills to list at index 17664. Found 175 skills.
# Converted string skills to list at index 4881. Found 26 skills.
# Converted string skills to list at index 12299. Found 129 skills.
# Converted string skills to list at index 22170. Found 49 skills.
# Converted string skills to list at index 1396. Found 47 skills.
# Converted string skills to list at index 2584. Found 40 skills.
# Converted string skills to list at index 25194. Found 35 skills.
# Converted string skills to list at index 12365. Found 224 skills.
# Converted string skills to list at index 26878. Found 41 skills.
# Converted string skills to list at index 18520. Found 81 skills.
# Converted string skills to list at index 7584. Found 23 skills.
# Converted string skills to list at index 27989. Found 40 skills.
# Converted string skills to list at index 3654. Found 31 skills.
# Converted string skills to list at index 32891. Found 33 skills.
# Converted string skills to list at index 16515. Found 52 skills.
# Converted string skills to list at index 23673. Found 17 skills.
# Converted string skills to list at index 11709. Found 57 skills.
# Converted string skills to list at index 32402. Found 36 skills.
# Converted string skills to list at index 8835. Found 81 skills.
# Converted string skills to list at index 9724. Found 143 skills.
# Converted string skills to list at index 7977. Found 47 skills.
# Converted string skills to list at index 8119. Found 213 skills.
# Converted string skills to list at index 8940. Found 48 skills.
# Converted string skills to list at index 30853. Found 50 skills.
# Converted string skills to list at index 27539. Found 32 skills.
# Converted string skills to list at index 12207. Found 135 skills.
# Converted string skills to list at index 33057. Found 81 skills.
# Converted string skills to list at index 8567. Found 39 skills.
# Converted string skills to list at index 34340. Found 43 skills.
# Converted string skills to list at index 33168. Found 12 skills.
# Converted string skills to list at index 30145. Found 33 skills.
# Converted string skills to list at index 17771. Found 152 skills.
# Converted string skills to list at index 13323. Found 97 skills.
# Converted string skills to list at index 12220. Found 63 skills.
# Converted string skills to list at index 17234. Found 48 skills.
# Converted string skills to list at index 14411. Found 21 skills.
# Converted string skills to list at index 12366. Found 111 skills.
# Converted string skills to list at index 462. Found 126 skills.
# Converted string skills to list at index 6211. Found 98 skills.
# Converted string skills to list at index 20966. Found 161 skills.
# Converted string skills to list at index 16866. Found 28 skills.
# Converted string skills to list at index 27272. Found 29 skills.
# Converted string skills to list at index 29352. Found 35 skills.
# Converted string skills to list at index 22522. Found 139 skills.
# Converted string skills to list at index 11480. Found 41 skills.
# Converted string skills to list at index 22191. Found 9 skills.
# Converted string skills to list at index 34024. Found 66 skills.
# Converted string skills to list at index 14279. Found 50 skills.
# Converted string skills to list at index 34420. Found 123 skills.
# Converted string skills to list at index 22302. Found 47 skills.
# Converted string skills to list at index 27328. Found 46 skills.
# Converted string skills to list at index 24532. Found 73 skills.
# Converted string skills to list at index 15581. Found 95 skills.
# Converted string skills to list at index 8603. Found 47 skills.
# Converted string skills to list at index 34034. Found 20 skills.
# Converted string skills to list at index 27958. Found 25 skills.
# Converted string skills to list at index 8120. Found 47 skills.
# Converted string skills to list at index 3521. Found 41 skills.
# Converted string skills to list at index 5992. Found 32 skills.
# Converted string skills to list at index 11302. Found 83 skills.
# Converted string skills to list at index 18204. Found 121 skills.
# Converted string skills to list at index 11737. Found 70 skills.
# Converted string skills to list at index 16948. Found 60 skills.
# Converted string skills to list at index 34396. Found 125 skills.
# Converted string skills to list at index 5483. Found 47 skills.
# Converted string skills to list at index 21020. Found 82 skills.
# Converted string skills to list at index 23174. Found 50 skills.
# Converted string skills to list at index 25849. Found 53 skills.
# Converted string skills to list at index 45. Found 118 skills.
# Converted string skills to list at index 28085. Found 20 skills.
# Converted string skills to list at index 20932. Found 49 skills.
# Converted string skills to list at index 11738. Found 47 skills.
# Converted string skills to list at index 20078. Found 30 skills.
# Converted string skills to list at index 16578. Found 61 skills.
# Converted string skills to list at index 12579. Found 183 skills.
# Converted string skills to list at index 6775. Found 30 skills.
# Converted string skills to list at index 5245. Found 39 skills.
# Converted string skills to list at index 28232. Found 38 skills.
# Converted string skills to list at index 29012. Found 137 skills.
# Converted string skills to list at index 33004. Found 50 skills.
# Converted string skills to list at index 3936. Found 37 skills.
# Converted string skills to list at index 34154. Found 57 skills.
# Converted string skills to list at index 7060. Found 175 skills.
# Converted string skills to list at index 10481. Found 64 skills.
# Converted string skills to list at index 32905. Found 18 skills.
# Converted string skills to list at index 3256. Found 47 skills.
# Converted string skills to list at index 11280. Found 40 skills.
# Converted string skills to list at index 5461. Found 56 skills.
# Converted string skills to list at index 11482. Found 47 skills.
# Converted string skills to list at index 29624. Found 39 skills.
# Converted string skills to list at index 5842. Found 108 skills.
# Converted string skills to list at index 22284. Found 56 skills.
# Converted string skills to list at index 5576. Found 110 skills.
# Converted string skills to list at index 6546. Found 39 skills.
# Converted string skills to list at index 1367. Found 102 skills.
# Converted string skills to list at index 21590. Found 36 skills.
# Converted string skills to list at index 7543. Found 106 skills.
# Converted string skills to list at index 22342. Found 25 skills.
# Converted string skills to list at index 24228. Found 47 skills.
# Converted string skills to list at index 6724. Found 154 skills.
# Converted string skills to list at index 34443. Found 413 skills.
# Converted string skills to list at index 5641. Found 38 skills.
# Converted string skills to list at index 6827. Found 71 skills.
# Converted string skills to list at index 450. Found 30 skills.
# Converted string skills to list at index 27688. Found 32 skills.
# Converted string skills to list at index 16587. Found 76 skills.
# Converted string skills to list at index 3405. Found 307 skills.
# Converted string skills to list at index 29260. Found 79 skills.
# Converted string skills to list at index 21350. Found 44 skills.
# Converted string skills to list at index 8777. Found 46 skills.
# Converted string skills to list at index 5898. Found 159 skills.
# Converted string skills to list at index 29936. Found 35 skills.
# Converted string skills to list at index 8711. Found 35 skills.
# Converted string skills to list at index 8373. Found 71 skills.
# Converted string skills to list at index 16487. Found 33 skills.
# Converted string skills to list at index 33532. Found 49 skills.
# Converted string skills to list at index 5476. Found 32 skills.
# Converted string skills to list at index 34435. Found 220 skills.
# Converted string skills to list at index 14051. Found 122 skills.
# Converted string skills to list at index 7164. Found 133 skills.
# Converted string skills to list at index 2047. Found 32 skills.
# Converted string skills to list at index 26499. Found 27 skills.
# Converted string skills to list at index 4300. Found 49 skills.
# Converted string skills to list at index 34059. Found 11 skills.
# Converted string skills to list at index 2607. Found 56 skills.
# Converted string skills to list at index 13998. Found 30 skills.
# Converted string skills to list at index 15252. Found 63 skills.
# Converted string skills to list at index 21639. Found 224 skills.
# Converted string skills to list at index 1167. Found 84 skills.
# Converted string skills to list at index 15390. Found 20 skills.
# Converted string skills to list at index 32440. Found 25 skills.
# Converted string skills to list at index 20228. Found 35 skills.
# Converted string skills to list at index 12851. Found 136 skills.
# Converted string skills to list at index 2493. Found 54 skills.
# Converted string skills to list at index 34434. Found 14 skills.
# Converted string skills to list at index 34427. Found 42 skills.
# Converted string skills to list at index 24152. Found 56 skills.
# Converted string skills to list at index 9949. Found 47 skills.
# Converted string skills to list at index 31023. Found 47 skills.
# Converted string skills to list at index 32275. Found 38 skills.
# Converted string skills to list at index 24429. Found 39 skills.
# Converted string skills to list at index 19549. Found 52 skills.
# Converted string skills to list at index 1067. Found 180 skills.
# Converted string skills to list at index 27405. Found 17 skills.
# Converted string skills to list at index 21926. Found 43 skills.
# Converted string skills to list at index 18711. Found 98 skills.
# Converted string skills to list at index 14135. Found 444 skills.
# Converted string skills to list at index 3673. Found 52 skills.
# Converted string skills to list at index 2773. Found 100 skills.
# Converted string skills to list at index 33284. Found 42 skills.
# Converted string skills to list at index 10446. Found 54 skills.
# Converted string skills to list at index 11157. Found 50 skills.
# Converted string skills to list at index 13831. Found 62 skills.
# Converted string skills to list at index 13442. Found 106 skills.
# Converted string skills to list at index 30230. Found 45 skills.
# Converted string skills to list at index 10591. Found 38 skills.
# Converted string skills to list at index 797. Found 141 skills.
# Converted string skills to list at index 7103. Found 71 skills.
# Converted string skills to list at index 14163. Found 187 skills.
# Converted string skills to list at index 17482. Found 228 skills.
# Converted string skills to list at index 23441. Found 89 skills.
# Converted string skills to list at index 8437. Found 40 skills.
# Converted string skills to list at index 22038. Found 23 skills.
# Converted string skills to list at index 26701. Found 43 skills.
# Converted string skills to list at index 18077. Found 101 skills.
# Converted string skills to list at index 20080. Found 50 skills.
# Converted string skills to list at index 30894. Found 36 skills.
# Converted string skills to list at index 23263. Found 73 skills.
# Converted string skills to list at index 6876. Found 36 skills.
# Converted string skills to list at index 30850. Found 114 skills.
# Converted string skills to list at index 25228. Found 100 skills.
# Converted string skills to list at index 34402. Found 101 skills.
# Converted string skills to list at index 18981. Found 73 skills.
# Converted string skills to list at index 6520. Found 26 skills.
# Converted string skills to list at index 9258. Found 49 skills.
# Converted string skills to list at index 24173. Found 39 skills.
# Converted string skills to list at index 32744. Found 37 skills.
# Converted string skills to list at index 14377. Found 64 skills.
# Converted string skills to list at index 3412. Found 78 skills.
# Converted string skills to list at index 4522. Found 17 skills.
# Converted string skills to list at index 34422. Found 134 skills.
# Converted string skills to list at index 21503. Found 306 skills.
# Converted string skills to list at index 15103. Found 35 skills.
# Converted string skills to list at index 4242. Found 198 skills.
# Converted string skills to list at index 4572. Found 26 skills.
# Converted string skills to list at index 16324. Found 43 skills.
# Converted string skills to list at index 16083. Found 68 skills.
# Converted string skills to list at index 3962. Found 79 skills.
# Converted string skills to list at index 21678. Found 66 skills.
# Converted string skills to list at index 3892. Found 108 skills.
# Converted string skills to list at index 12645. Found 100 skills.
# Converted string skills to list at index 34433. Found 81 skills.
# Converted string skills to list at index 33502. Found 29 skills.
# Converted string skills to list at index 33951. Found 22 skills.
# Converted string skills to list at index 23103. Found 70 skills.
# Converted string skills to list at index 33758. Found 41 skills.
# Converted string skills to list at index 23277. Found 57 skills.
# Converted string skills to list at index 4067. Found 30 skills.
# Converted string skills to list at index 671. Found 99 skills.
# Converted string skills to list at index 15321. Found 68 skills.
# Converted string skills to list at index 20088. Found 143 skills.
# Converted string skills to list at index 2192. Found 32 skills.
# Converted string skills to list at index 2138. Found 122 skills.
# Converted string skills to list at index 12413. Found 86 skills.
# Converted string skills to list at index 6609. Found 138 skills.
# Converted string skills to list at index 21734. Found 68 skills.
# Converted string skills to list at index 32321. Found 30 skills.
# Converted string skills to list at index 22961. Found 54 skills.
# Converted string skills to list at index 28679. Found 23 skills.
# Converted string skills to list at index 4204. Found 45 skills.
# Converted string skills to list at index 16759. Found 38 skills.
# Converted string skills to list at index 6976. Found 93 skills.
# Converted string skills to list at index 16224. Found 17 skills.
# Converted string skills to list at index 24527. Found 207 skills.
# Converted string skills to list at index 32646. Found 48 skills.
# Converted string skills to list at index 24882. Found 61 skills.
# Converted string skills to list at index 6881. Found 28 skills.
# Converted string skills to list at index 15262. Found 121 skills.
# Converted string skills to list at index 31259. Found 20 skills.
# Converted string skills to list at index 30014. Found 25 skills.
# Converted string skills to list at index 26053. Found 71 skills.
# Converted string skills to list at index 14608. Found 70 skills.
# Converted string skills to list at index 9669. Found 58 skills.
# Converted string skills to list at index 34339. Found 25 skills.
# Converted string skills to list at index 12623. Found 80 skills.
# Converted string skills to list at index 23439. Found 45 skills.
# Converted string skills to list at index 1009. Found 45 skills.
# Converted string skills to list at index 199. Found 59 skills.
# Converted string skills to list at index 22201. Found 50 skills.
# Converted string skills to list at index 9620. Found 71 skills.
# Converted string skills to list at index 20905. Found 44 skills.
# Converted string skills to list at index 28700. Found 28 skills.
# Converted string skills to list at index 27024. Found 25 skills.
# Converted string skills to list at index 19491. Found 28 skills.
# Converted string skills to list at index 15159. Found 63 skills.
# Converted string skills to list at index 8436. Found 71 skills.
# Converted string skills to list at index 7054. Found 124 skills.
# Converted string skills to list at index 11250. Found 61 skills.
# Converted string skills to list at index 19323. Found 36 skills.
# Converted string skills to list at index 12221. Found 91 skills.
# Converted string skills to list at index 33349. Found 20 skills.
# Converted string skills to list at index 621. Found 83 skills.
# Converted string skills to list at index 9308. Found 72 skills.
# Converted string skills to list at index 1158. Found 95 skills.
# Converted string skills to list at index 13486. Found 108 skills.
# Converted string skills to list at index 8424. Found 22 skills.
# Converted string skills to list at index 25353. Found 45 skills.
# Converted string skills to list at index 32034. Found 27 skills.
# Converted string skills to list at index 34428. Found 80 skills.
# Converted string skills to list at index 22606. Found 30 skills.
# Converted string skills to list at index 12935. Found 99 skills.
# Converted string skills to list at index 16908. Found 51 skills.
# Converted string skills to list at index 21021. Found 122 skills.
# Converted string skills to list at index 34167. Found 49 skills.
# Converted string skills to list at index 22204. Found 43 skills.
# Converted string skills to list at index 7938. Found 51 skills.
# Converted string skills to list at index 24104. Found 42 skills.
# Converted string skills to list at index 17733. Found 41 skills.
# Converted string skills to list at index 8758. Found 40 skills.
# Converted string skills to list at index 3975. Found 111 skills.
# Converted string skills to list at index 21379. Found 53 skills.
# Converted string skills to list at index 20576. Found 89 skills.
# Converted string skills to list at index 23696. Found 32 skills.
# Converted string skills to list at index 31275. Found 25 skills.
# Converted string skills to list at index 11096. Found 68 skills.
# Converted string skills to list at index 7161. Found 65 skills.
# Converted string skills to list at index 32688. Found 57 skills.
# Converted string skills to list at index 33517. Found 26 skills.
# Converted string skills to list at index 17144. Found 111 skills.
# Converted string skills to list at index 33950. Found 20 skills.
# Converted string skills to list at index 6201. Found 33 skills.
# Converted string skills to list at index 3449. Found 89 skills.
# Converted string skills to list at index 18094. Found 41 skills.
# Converted string skills to list at index 27982. Found 43 skills.
# Converted string skills to list at index 23432. Found 179 skills.
# Converted string skills to list at index 10588. Found 56 skills.
# Converted string skills to list at index 3247. Found 38 skills.
# Converted string skills to list at index 17743. Found 38 skills.
# Converted string skills to list at index 23972. Found 75 skills.
# Converted string skills to list at index 19559. Found 67 skills.
# Converted string skills to list at index 7230. Found 127 skills.
# Converted string skills to list at index 10296. Found 60 skills.
# Converted string skills to list at index 8751. Found 109 skills.
# Converted string skills to list at index 19801. Found 41 skills.
# Converted string skills to list at index 4769. Found 32 skills.
# Converted string skills to list at index 30810. Found 16 skills.
# Converted string skills to list at index 20696. Found 61 skills.
# Converted string skills to list at index 30066. Found 37 skills.
# Converted string skills to list at index 32910. Found 62 skills.
# Converted string skills to list at index 5293. Found 68 skills.
# Converted string skills to list at index 4760. Found 55 skills.
# Converted string skills to list at index 19169. Found 33 skills.
# Converted string skills to list at index 26532. Found 167 skills.
# Converted string skills to list at index 2632. Found 75 skills.
# Converted string skills to list at index 26719. Found 38 skills.
# Converted string skills to list at index 33246. Found 37 skills.
# Converted string skills to list at index 14190. Found 30 skills.
# Converted string skills to list at index 10170. Found 38 skills.
# Converted string skills to list at index 2320. Found 22 skills.
# Converted string skills to list at index 13288. Found 71 skills.
# Converted string skills to list at index 7579. Found 85 skills.
# Converted string skills to list at index 34444. Found 96 skills.
# Converted string skills to list at index 31133. Found 59 skills.
# Converted string skills to list at index 34401. Found 39 skills.
# Converted string skills to list at index 9790. Found 41 skills.
# Converted string skills to list at index 17661. Found 176 skills.
# Converted string skills to list at index 28439. Found 29 skills.
# Converted string skills to list at index 11648. Found 64 skills.
# Converted string skills to list at index 12998. Found 86 skills.
# Converted string skills to list at index 34412. Found 154 skills.
# Converted string skills to list at index 6031. Found 46 skills.
# Converted string skills to list at index 5216. Found 27 skills.
# Converted string skills to list at index 34409. Found 140 skills.
# Converted string skills to list at index 2478. Found 23 skills.
# Converted string skills to list at index 13408. Found 79 skills.
# Converted string skills to list at index 33685. Found 49 skills.
# Converted string skills to list at index 5727. Found 172 skills.
# Converted string skills to list at index 19133. Found 40 skills.
# Converted string skills to list at index 15465. Found 25 skills.
# Converted string skills to list at index 23755. Found 47 skills.
# Converted string skills to list at index 12164. Found 193 skills.
# Converted string skills to list at index 1134. Found 66 skills.
# Converted string skills to list at index 31136. Found 44 skills.
# Converted string skills to list at index 29895. Found 27 skills.
# Converted string skills to list at index 30528. Found 39 skills.
# Converted string skills to list at index 16057. Found 168 skills.
# Converted string skills to list at index 21824. Found 51 skills.
# Converted string skills to list at index 23682. Found 64 skills.
# Converted string skills to list at index 1889. Found 78 skills.
# Converted string skills to list at index 6865. Found 103 skills.
# Converted string skills to list at index 9054. Found 52 skills.
# Converted string skills to list at index 30967. Found 27 skills.
# Converted string skills to list at index 25376. Found 29 skills.
# Converted string skills to list at index 28670. Found 39 skills.
# Converted string skills to list at index 31975. Found 43 skills.
# Converted string skills to list at index 6209. Found 40 skills.
# Converted string skills to list at index 11235. Found 40 skills.
# Converted string skills to list at index 23053. Found 50 skills.
# Converted string skills to list at index 28390. Found 30 skills.
# Converted string skills to list at index 1038. Found 44 skills.
# Converted string skills to list at index 5342. Found 78 skills.
# Converted string skills to list at index 12216. Found 75 skills.
# Converted string skills to list at index 9618. Found 52 skills.
# Converted string skills to list at index 32900. Found 39 skills.
# Converted string skills to list at index 34410. Found 711 skills.
# Converted string skills to list at index 7273. Found 48 skills.
# Converted string skills to list at index 4673. Found 30 skills.
# Converted string skills to list at index 23501. Found 41 skills.
# Converted string skills to list at index 7055. Found 48 skills.
# Converted string skills to list at index 11503. Found 138 skills.
# Converted string skills to list at index 28706. Found 33 skills.
# Converted string skills to list at index 27296. Found 68 skills.
# Converted string skills to list at index 27695. Found 34 skills.
# Converted string skills to list at index 26134. Found 148 skills.
# Converted string skills to list at index 25157. Found 63 skills.
# Converted string skills to list at index 20930. Found 15 skills.
# Converted string skills to list at index 34429. Found 99 skills.
# Converted string skills to list at index 2312. Found 41 skills.
# Converted string skills to list at index 33122. Found 73 skills.
# Converted string skills to list at index 6278. Found 53 skills.
# Converted string skills to list at index 28432. Found 63 skills.
# Converted string skills to list at index 6756. Found 67 skills.
# Converted string skills to list at index 1031. Found 39 skills.
# Converted string skills to list at index 20665. Found 101 skills.
# Converted string skills to list at index 2393. Found 128 skills.
# Converted string skills to list at index 34416. Found 213 skills.
# Converted string skills to list at index 31330. Found 25 skills.
# Converted string skills to list at index 20900. Found 31 skills.
# Converted string skills to list at index 26343. Found 45 skills.
# Converted string skills to list at index 19374. Found 36 skills.
# Converted string skills to list at index 11056. Found 369 skills.
# Converted string skills to list at index 24661. Found 48 skills.
# Converted string skills to list at index 8541. Found 37 skills.
# Converted string skills to list at index 1205. Found 35 skills.
# Converted string skills to list at index 29606. Found 49 skills.
# Converted string skills to list at index 17306. Found 122 skills.
# Converted string skills to list at index 34397. Found 53 skills.
# Converted string skills to list at index 14044. Found 96 skills.
# Converted string skills to list at index 8612. Found 27 skills.
# Converted string skills to list at index 1872. Found 173 skills.
# Converted string skills to list at index 34411. Found 78 skills.
# Converted string skills to list at index 14357. Found 40 skills.
# Converted string skills to list at index 19109. Found 86 skills.
# Converted string skills to list at index 34413. Found 78 skills.
# Converted string skills to list at index 31703. Found 17 skills.
# Converted string skills to list at index 34400. Found 113 skills.
# Converted string skills to list at index 7564. Found 39 skills.
# Converted string skills to list at index 31771. Found 23 skills.
# Converted string skills to list at index 32142. Found 65 skills.
# Converted string skills to list at index 20455. Found 57 skills.
# Converted string skills to list at index 34415. Found 52 skills.
# Converted string skills to list at index 30983. Found 41 skills.
# Converted string skills to list at index 23269. Found 120 skills.
# Converted string skills to list at index 34414. Found 96 skills.
# Converted string skills to list at index 6513. Found 26 skills.
# Converted string skills to list at index 26782. Found 44 skills.
# Converted string skills to list at index 6197. Found 48 skills.
# Converted string skills to list at index 34202. Found 31 skills.
# Converted string skills to list at index 26716. Found 14 skills.
# Converted string skills to list at index 28675. Found 41 skills.
# Converted string skills to list at index 4477. Found 42 skills.
# Converted string skills to list at index 8542. Found 70 skills.
# Converted string skills to list at index 26354. Found 125 skills.
# Converted string skills to list at index 4226. Found 64 skills.
# Converted string skills to list at index 16424. Found 26 skills.
# Converted string skills to list at index 16315. Found 35 skills.
# Converted string skills to list at index 28621. Found 12 skills.
# Converted string skills to list at index 23639. Found 55 skills.
# Converted string skills to list at index 29374. Found 34 skills.
# Converted string skills to list at index 4894. Found 32 skills.
# Converted string skills to list at index 2556. Found 45 skills.
# Converted string skills to list at index 6146. Found 42 skills.
# Converted string skills to list at index 15545. Found 71 skills.
# Converted string skills to list at index 34313. Found 38 skills.
# Converted string skills to list at index 8088. Found 162 skills.
# Converted string skills to list at index 31544. Found 19 skills.
# Converted string skills to list at index 32884. Found 58 skills.
# Converted string skills to list at index 557. Found 64 skills.
# Converted string skills to list at index 30998. Found 28 skills.
# Converted string skills to list at index 1737. Found 71 skills.
# Converted string skills to list at index 18296. Found 85 skills.
# Converted string skills to list at index 26282. Found 37 skills.
# Converted string skills to list at index 9461. Found 46 skills.
# Converted string skills to list at index 11562. Found 48 skills.
# Converted string skills to list at index 28469. Found 58 skills.
# Converted string skills to list at index 23050. Found 71 skills.
# Converted string skills to list at index 24847. Found 48 skills.
# Converted string skills to list at index 32117. Found 42 skills.
# Converted string skills to list at index 27603. Found 62 skills.
# Converted string skills to list at index 9759. Found 39 skills.
# Converted string skills to list at index 24299. Found 25 skills.
# Converted string skills to list at index 11432. Found 44 skills.
# Converted string skills to list at index 16165. Found 61 skills.
# Converted string skills to list at index 6111. Found 85 skills.
# Converted string skills to list at index 29813. Found 33 skills.
# Converted string skills to list at index 25593. Found 63 skills.
# Converted string skills to list at index 32823. Found 26 skills.
# Converted string skills to list at index 22211. Found 31 skills.
# Converted string skills to list at index 29923. Found 30 skills.
# Converted string skills to list at index 19833. Found 94 skills.
# Converted string skills to list at index 5979. Found 163 skills.
# Converted string skills to list at index 5936. Found 39 skills.
# Converted string skills to list at index 27627. Found 70 skills.
# Converted string skills to list at index 33803. Found 33 skills.
# Converted string skills to list at index 34442. Found 105 skills.
# Converted string skills to list at index 26544. Found 57 skills.
# Converted string skills to list at index 13239. Found 306 skills.
# Converted string skills to list at index 18860. Found 73 skills.
# Converted string skills to list at index 12231. Found 495 skills.
# Converted string skills to list at index 7165. Found 26 skills.
# Converted string skills to list at index 5214. Found 428 skills.
# Converted string skills to list at index 31766. Found 45 skills.
# Converted string skills to list at index 24269. Found 41 skills.
# Converted string skills to list at index 5786. Found 151 skills.
# Converted string skills to list at index 34404. Found 102 skills.
# Converted string skills to list at index 7675. Found 36 skills.
# Converted string skills to list at index 24290. Found 35 skills.
# Converted string skills to list at index 10686. Found 78 skills.
# Converted string skills to list at index 11304. Found 24 skills.
# Converted string skills to list at index 15502. Found 21 skills.
# Converted string skills to list at index 5138. Found 35 skills.
# Converted string skills to list at index 7155. Found 64 skills.
# Converted string skills to list at index 7898. Found 41 skills.
# Converted string skills to list at index 17374. Found 148 skills.
# Converted string skills to list at index 9123. Found 35 skills.
# Converted string skills to list at index 16182. Found 215 skills.
# Converted string skills to list at index 31551. Found 26 skills.
# Converted string skills to list at index 29082. Found 28 skills.
# Converted string skills to list at index 32775. Found 98 skills.
# Converted string skills to list at index 5370. Found 32 skills.
# Converted string skills to list at index 25450. Found 55 skills.
# Converted string skills to list at index 15529. Found 231 skills.
# Converted string skills to list at index 29653. Found 27 skills.
# Converted string skills to list at index 29139. Found 27 skills.
# Converted string skills to list at index 33282. Found 25 skills.
# Converted string skills to list at index 8291. Found 36 skills.
# Converted string skills to list at index 25649. Found 48 skills.
# Converted string skills to list at index 33335. Found 27 skills.
# Converted string skills to list at index 28659. Found 122 skills.
# Converted string skills to list at index 30385. Found 9 skills.
# Converted string skills to list at index 33355. Found 14 skills.
# Converted string skills to list at index 24876. Found 77 skills.
# Converted string skills to list at index 31307. Found 35 skills.
# Converted string skills to list at index 28732. Found 32 skills.
# Converted string skills to list at index 14964. Found 40 skills.
# Converted string skills to list at index 34417. Found 96 skills.
# Converted string skills to list at index 20618. Found 108 skills.
# Converted string skills to list at index 10095. Found 63 skills.
# Converted string skills to list at index 30819. Found 56 skills.
# Converted string skills to list at index 17522. Found 84 skills.
# Converted string skills to list at index 20095. Found 41 skills.
# Converted string skills to list at index 4513. Found 57 skills.
# Converted string skills to list at index 27886. Found 29 skills.
# Converted string skills to list at index 8646. Found 42 skills.
# Converted string skills to list at index 32268. Found 37 skills.
# Converted string skills to list at index 24236. Found 62 skills.
# Converted string skills to list at index 27021. Found 50 skills.
# Converted string skills to list at index 14298. Found 46 skills.
# Converted string skills to list at index 34426. Found 93 skills.
# Converted string skills to list at index 31530. Found 35 skills.
# Converted string skills to list at index 8687. Found 26 skills.
# Converted string skills to list at index 29708. Found 46 skills.
# Converted string skills to list at index 27277. Found 74 skills.
# Converted string skills to list at index 12041. Found 112 skills.
# Converted string skills to list at index 26041. Found 80 skills.
# Converted string skills to list at index 16116. Found 71 skills.
# Converted string skills to list at index 32934. Found 30 skills.
# Converted string skills to list at index 28527. Found 24 skills.
# Converted string skills to list at index 13790. Found 90 skills.
# Converted string skills to list at index 9671. Found 103 skills.
# Converted string skills to list at index 25013. Found 91 skills.
# Converted string skills to list at index 25342. Found 23 skills.
# Converted string skills to list at index 10939. Found 44 skills.
# Converted string skills to list at index 14408. Found 35 skills.
# Converted string skills to list at index 14677. Found 45 skills.
# Converted string skills to list at index 8443. Found 52 skills.
# Converted string skills to list at index 34399. Found 210 skills.
# Converted string skills to list at index 30680. Found 43 skills.
# Converted string skills to list at index 19165. Found 27 skills.
# Converted string skills to list at index 13232. Found 80 skills.
# Converted string skills to list at index 20478. Found 78 skills.
# Converted string skills to list at index 25484. Found 63 skills.
# Converted string skills to list at index 34432. Found 145 skills.
# Converted string skills to list at index 33697. Found 30 skills.
# Converted string skills to list at index 33027. Found 34 skills.
# Converted string skills to list at index 24591. Found 43 skills.
# Converted string skills to list at index 31878. Found 29 skills.
# Converted string skills to list at index 26002. Found 56 skills.
# Converted string skills to list at index 31555. Found 21 skills.
# Converted string skills to list at index 22372. Found 54 skills.
# Converted string skills to list at index 34403. Found 198 skills.
# Converted string skills to list at index 23246. Found 87 skills.
# Converted string skills to list at index 3703. Found 205 skills.
# Converted string skills to list at index 8856. Found 108 skills.
# Converted string skills to list at index 28107. Found 42 skills.
# Converted string skills to list at index 6395. Found 49 skills.
# Converted string skills to list at index 21131. Found 57 skills.
# Converted string skills to list at index 1592. Found 48 skills.
# Converted string skills to list at index 22003. Found 42 skills.
# Converted string skills to list at index 6755. Found 80 skills.
# Converted string skills to list at index 26370. Found 49 skills.
# Converted string skills to list at index 32839. Found 62 skills.
# Converted string skills to list at index 31970. Found 26 skills.
# Converted string skills to list at index 31596. Found 42 skills.
# Converted string skills to list at index 34261. Found 41 skills.
# Converted string skills to list at index 29197. Found 31 skills.
# Converted string skills to list at index 4119. Found 118 skills.
# Converted string skills to list at index 22718. Found 52 skills.
# Converted string skills to list at index 8848. Found 30 skills.
# Converted string skills to list at index 29454. Found 38 skills.
# Converted string skills to list at index 23097. Found 40 skills.
# Converted string skills to list at index 27850. Found 46 skills.
# Converted string skills to list at index 18597. Found 96 skills.
# Converted string skills to list at index 22319. Found 40 skills.
# Converted string skills to list at index 32375. Found 23 skills.
# Converted string skills to list at index 8005. Found 44 skills.
# Converted string skills to list at index 15127. Found 54 skills.
# Converted string skills to list at index 15362. Found 52 skills.
# Converted string skills to list at index 30446. Found 250 skills.
# Converted string skills to list at index 34418. Found 51 skills.
# Converted string skills to list at index 8233. Found 34 skills.
# Converted string skills to list at index 207. Found 136 skills.
# Converted string skills to list at index 30533. Found 25 skills.
# Converted string skills to list at index 25757. Found 135 skills.
# Converted string skills to list at index 32933. Found 29 skills.
# Converted string skills to list at index 24425. Found 73 skills.
# Converted string skills to list at index 29317. Found 26 skills.
# Converted string skills to list at index 22178. Found 64 skills.
# Converted string skills to list at index 28938. Found 54 skills.
# Converted string skills to list at index 27592. Found 44 skills.
# Converted string skills to list at index 4145. Found 89 skills.
# Converted string skills to list at index 28991. Found 14 skills.
# Converted string skills to list at index 23073. Found 56 skills.
# Converted string skills to list at index 15921. Found 71 skills.
# Converted string skills to list at index 20311. Found 46 skills.
# Converted string skills to list at index 2353. Found 27 skills.
# Converted string skills to list at index 1481. Found 74 skills.
# Converted string skills to list at index 30837. Found 41 skills.
# Converted string skills to list at index 7804. Found 59 skills.
# Converted string skills to list at index 5546. Found 69 skills.
# Converted string skills to list at index 1347. Found 55 skills.
# Converted string skills to list at index 32428. Found 42 skills.
# Converted string skills to list at index 8625. Found 53 skills.
# Converted string skills to list at index 19926. Found 142 skills.
# Converted string skills to list at index 30609. Found 38 skills.
# Converted string skills to list at index 14504. Found 87 skills.
# Converted string skills to list at index 11239. Found 43 skills.
# Converted string skills to list at index 16272. Found 42 skills.
# Converted string skills to list at index 27174. Found 54 skills.
# Converted string skills to list at index 15108. Found 102 skills.
# Converted string skills to list at index 23699. Found 56 skills.
# Converted string skills to list at index 20135. Found 52 skills.
# Converted string skills to list at index 5623. Found 51 skills.
# Converted string skills to list at index 2799. Found 154 skills.
# Converted string skills to list at index 19157. Found 127 skills.
# Converted string skills to list at index 26025. Found 172 skills.
# Converted string skills to list at index 5348. Found 493 skills.
# Converted string skills to list at index 34421. Found 109 skills.
# Converted string skills to list at index 21019. Found 117 skills.
# Converted string skills to list at index 2923. Found 49 skills.
# Converted string skills to list at index 31896. Found 45 skills.
# Converted string skills to list at index 949. Found 25 skills.
# Converted string skills to list at index 6218. Found 26 skills.
# Converted string skills to list at index 1995. Found 26 skills.
# Converted string skills to list at index 20068. Found 29 skills.
# Converted string skills to list at index 14527. Found 29 skills.
# Converted string skills to list at index 7198. Found 62 skills.
# Converted string skills to list at index 30336. Found 65 skills.
# Converted string skills to list at index 8226. Found 60 skills.
# Converted string skills to list at index 31060. Found 17 skills.
# Converted string skills to list at index 2549. Found 21 skills.
# Converted string skills to list at index 12826. Found 81 skills.
# Converted string skills to list at index 29793. Found 35 skills.
# Converted string skills to list at index 28694. Found 49 skills.
# Converted string skills to list at index 28755. Found 54 skills.
# Converted string skills to list at index 11338. Found 33 skills.
# Converted string skills to list at index 28145. Found 96 skills.
# Converted string skills to list at index 9360. Found 42 skills.
# Converted string skills to list at index 28969. Found 30 skills.
# Converted string skills to list at index 18692. Found 145 skills.
# Converted string skills to list at index 18511. Found 60 skills.
# Converted string skills to list at index 34441. Found 100 skills.
# Converted string skills to list at index 31996. Found 45 skills.
# Converted string skills to list at index 10232. Found 57 skills.
# Converted string skills to list at index 7894. Found 114 skills.
# Converted string skills to list at index 6436. Found 102 skills.
# Converted string skills to list at index 22359. Found 36 skills.
# Converted string skills to list at index 29069. Found 61 skills.
# Converted string skills to list at index 15505. Found 63 skills.
# Converted string skills to list at index 28215. Found 47 skills.
# Converted string skills to list at index 19239. Found 87 skills.
# Converted string skills to list at index 32196. Found 56 skills.
# Converted string skills to list at index 30600. Found 26 skills.
# Converted string skills to list at index 4254. Found 74 skills.
# Converted string skills to list at index 22808. Found 42 skills.
# Converted string skills to list at index 15010. Found 59 skills.
# Converted string skills to list at index 100. Found 40 skills.
# Converted string skills to list at index 34137. Found 42 skills.
# Converted string skills to list at index 22664. Found 365 skills.
# Converted string skills to list at index 3531. Found 60 skills.
# Converted string skills to list at index 7986. Found 20 skills.
# Converted string skills to list at index 1557. Found 16 skills.
# Converted string skills to list at index 30800. Found 17 skills.
# Converted string skills to list at index 20593. Found 76 skills.
# Converted string skills to list at index 16779. Found 11 skills.
# Converted string skills to list at index 18348. Found 208 skills.
# Converted string skills to list at index 14101. Found 64 skills.
# Converted string skills to list at index 3953. Found 37 skills.
# Converted string skills to list at index 12902. Found 151 skills.
# Converted string skills to list at index 22784. Found 77 skills.
# Converted string skills to list at index 13063. Found 229 skills.
# Converted string skills to list at index 30803. Found 33 skills.
# Converted string skills to list at index 8852. Found 45 skills.
# Converted string skills to list at index 889. Found 24 skills.
# Converted string skills to list at index 11964. Found 42 skills.
# Converted string skills to list at index 24134. Found 50 skills.
# Converted string skills to list at index 14972. Found 75 skills.
# Converted string skills to list at index 10448. Found 35 skills.
# Converted string skills to list at index 6595. Found 69 skills.
# Converted string skills to list at index 32760. Found 24 skills.
# Converted string skills to list at index 34437. Found 108 skills.
# Converted string skills to list at index 26024. Found 65 skills.
# Converted string skills to list at index 32049. Found 31 skills.
# Converted string skills to list at index 19541. Found 50 skills.
# Converted string skills to list at index 34425. Found 55 skills.
# Converted string skills to list at index 20475. Found 92 skills.
# Converted string skills to list at index 32330. Found 25 skills.
# Converted string skills to list at index 8913. Found 59 skills.
# Converted string skills to list at index 22835. Found 88 skills.
# Converted string skills to list at index 33544. Found 31 skills.
# Converted string skills to list at index 22715. Found 24 skills.
# Converted string skills to list at index 27679. Found 50 skills.
# Converted string skills to list at index 7255. Found 65 skills.
# Converted string skills to list at index 30862. Found 34 skills.
# Converted string skills to list at index 28110. Found 47 skills.
# Converted string skills to list at index 19204. Found 114 skills.
# Converted string skills to list at index 27532. Found 49 skills.
# Converted string skills to list at index 20653. Found 23 skills.
# Converted string skills to list at index 2648. Found 116 skills.
# Converted string skills to list at index 19180. Found 57 skills.
# Converted string skills to list at index 22638. Found 103 skills.
# Converted string skills to list at index 33007. Found 30 skills.
# Converted string skills to list at index 29760. Found 26 skills.
# Converted string skills to list at index 9372. Found 66 skills.
# Converted string skills to list at index 1150. Found 86 skills.
# Converted string skills to list at index 11949. Found 125 skills.
# Converted string skills to list at index 18573. Found 141 skills.
# Converted string skills to list at index 6420. Found 47 skills.
# Converted string skills to list at index 10580. Found 150 skills.
# Converted string skills to list at index 7362. Found 59 skills.
# Converted string skills to list at index 14729. Found 37 skills.
# Converted string skills to list at index 31630. Found 14 skills.
# Converted string skills to list at index 16154. Found 126 skills.
# Converted string skills to list at index 19974. Found 72 skills.
# Converted string skills to list at index 13048. Found 165 skills.
# Converted string skills to list at index 30544. Found 13 skills.
# Converted string skills to list at index 11803. Found 32 skills.
# Converted string skills to list at index 26579. Found 58 skills.
# Converted string skills to list at index 5453. Found 27 skills.
# Converted string skills to list at index 26686. Found 59 skills.
# Converted string skills to list at index 33373. Found 33 skills.
# Converted string skills to list at index 4156. Found 24 skills.
# Converted string skills to list at index 14295. Found 53 skills.
# Converted string skills to list at index 3777. Found 58 skills.
# Converted string skills to list at index 18529. Found 100 skills.
# Converted string skills to list at index 12447. Found 118 skills.
# Converted string skills to list at index 8174. Found 63 skills.
# Converted string skills to list at index 19010. Found 105 skills.
# Converted string skills to list at index 4914. Found 46 skills.
# Converted string skills to list at index 24451. Found 51 skills.
# Converted string skills to list at index 1148. Found 75 skills.
# Converted string skills to list at index 28131. Found 36 skills.
# Converted string skills to list at index 3315. Found 208 skills.
# Converted string skills to list at index 4275. Found 75 skills.
# Converted string skills to list at index 10292. Found 58 skills.
# Converted string skills to list at index 33059. Found 45 skills.
# Converted string skills to list at index 17191. Found 158 skills.
# Converted string skills to list at index 4208. Found 198 skills.
# Processed 759 rows with 0 errors. Generated 759 valid examples.
# Converted string skills to list at index 7715. Found 50 skills.
# Converted string skills to list at index 26554. Found 94 skills.
# Converted string skills to list at index 27907. Found 226 skills.
# Converted string skills to list at index 29313. Found 31 skills.
# Converted string skills to list at index 30716. Found 34 skills.
# Converted string skills to list at index 30312. Found 33 skills.
# Converted string skills to list at index 32226. Found 58 skills.
# Converted string skills to list at index 34419. Found 244 skills.
# Converted string skills to list at index 19972. Found 59 skills.
# Converted string skills to list at index 6832. Found 66 skills.
# Converted string skills to list at index 8112. Found 47 skills.
# Converted string skills to list at index 10727. Found 49 skills.
# Converted string skills to list at index 2649. Found 15 skills.
# Converted string skills to list at index 18902. Found 131 skills.
# Converted string skills to list at index 34438. Found 136 skills.
# Converted string skills to list at index 3472. Found 30 skills.
# Converted string skills to list at index 16129. Found 50 skills.
# Converted string skills to list at index 8184. Found 83 skills.
# Converted string skills to list at index 4298. Found 63 skills.
# Converted string skills to list at index 29277. Found 74 skills.
# Converted string skills to list at index 15621. Found 183 skills.
# Converted string skills to list at index 22555. Found 99 skills.
# Converted string skills to list at index 14016. Found 88 skills.
# Converted string skills to list at index 8115. Found 45 skills.
# Converted string skills to list at index 1160. Found 109 skills.
# Converted string skills to list at index 24184. Found 60 skills.
# Converted string skills to list at index 21309. Found 74 skills.
# Converted string skills to list at index 18521. Found 123 skills.
# Converted string skills to list at index 24563. Found 67 skills.
# Converted string skills to list at index 1428. Found 42 skills.
# Converted string skills to list at index 31424. Found 59 skills.
# Converted string skills to list at index 24578. Found 90 skills.
# Converted string skills to list at index 26988. Found 32 skills.
# Converted string skills to list at index 8629. Found 27 skills.
# Converted string skills to list at index 3210. Found 47 skills.
# Converted string skills to list at index 5578. Found 63 skills.
# Converted string skills to list at index 11317. Found 47 skills.
# Converted string skills to list at index 5636. Found 92 skills.
# Converted string skills to list at index 30084. Found 47 skills.
# Converted string skills to list at index 28668. Found 48 skills.
# Converted string skills to list at index 1964. Found 50 skills.
# Converted string skills to list at index 12567. Found 186 skills.
# Converted string skills to list at index 10091. Found 32 skills.
# Converted string skills to list at index 19484. Found 45 skills.
# Converted string skills to list at index 3724. Found 20 skills.
# Converted string skills to list at index 11947. Found 37 skills.
# Converted string skills to list at index 22959. Found 56 skills.
# Converted string skills to list at index 9688. Found 65 skills.
# Converted string skills to list at index 3263. Found 32 skills.
# Converted string skills to list at index 6577. Found 71 skills.
# Converted string skills to list at index 26619. Found 28 skills.
# Converted string skills to list at index 4131. Found 34 skills.
# Converted string skills to list at index 10710. Found 57 skills.
# Converted string skills to list at index 33348. Found 19 skills.
# Converted string skills to list at index 14285. Found 33 skills.
# Converted string skills to list at index 25429. Found 60 skills.
# Converted string skills to list at index 27773. Found 71 skills.
# Converted string skills to list at index 24655. Found 125 skills.
# Converted string skills to list at index 30554. Found 21 skills.
# Converted string skills to list at index 14552. Found 51 skills.
# Converted string skills to list at index 14598. Found 37 skills.
# Converted string skills to list at index 18342. Found 55 skills.
# Converted string skills to list at index 14992. Found 28 skills.
# Converted string skills to list at index 23027. Found 27 skills.
# Converted string skills to list at index 7711. Found 44 skills.
# Converted string skills to list at index 2819. Found 90 skills.
# Converted string skills to list at index 30899. Found 12 skills.
# Converted string skills to list at index 13083. Found 182 skills.
# Converted string skills to list at index 23030. Found 90 skills.
# Converted string skills to list at index 11859. Found 50 skills.
# Converted string skills to list at index 17524. Found 30 skills.
# Converted string skills to list at index 12609. Found 165 skills.
# Converted string skills to list at index 3873. Found 38 skills.
# Converted string skills to list at index 9336. Found 46 skills.
# Converted string skills to list at index 19243. Found 25 skills.
# Converted string skills to list at index 34430. Found 117 skills.
# Converted string skills to list at index 26421. Found 97 skills.
# Converted string skills to list at index 17494. Found 154 skills.
# Converted string skills to list at index 9755. Found 126 skills.
# Converted string skills to list at index 20496. Found 39 skills.
# Converted string skills to list at index 30295. Found 35 skills.
# Converted string skills to list at index 22019. Found 34 skills.
# Converted string skills to list at index 34395. Found 122 skills.
# Converted string skills to list at index 33003. Found 33 skills.
# Converted string skills to list at index 25967. Found 47 skills.
# Converted string skills to list at index 32305. Found 36 skills.
# Converted string skills to list at index 24750. Found 80 skills.
# Converted string skills to list at index 32320. Found 32 skills.
# Converted string skills to list at index 6648. Found 75 skills.
# Converted string skills to list at index 26785. Found 32 skills.
# Converted string skills to list at index 31683. Found 40 skills.
# Converted string skills to list at index 21470. Found 126 skills.
# Converted string skills to list at index 20809. Found 168 skills.
# Converted string skills to list at index 13051. Found 151 skills.
# Converted string skills to list at index 13024. Found 112 skills.
# Converted string skills to list at index 34146. Found 61 skills.
# Converted string skills to list at index 3339. Found 40 skills.
# Converted string skills to list at index 22035. Found 65 skills.
# Converted string skills to list at index 2257. Found 28 skills.
# Converted string skills to list at index 34440. Found 162 skills.
# Converted string skills to list at index 16147. Found 95 skills.
# Converted string skills to list at index 23930. Found 97 skills.
# Converted string skills to list at index 9164. Found 64 skills.
# Converted string skills to list at index 33564. Found 52 skills.
# Converted string skills to list at index 10004. Found 82 skills.
# Converted string skills to list at index 34407. Found 117 skills.
# Converted string skills to list at index 8167. Found 132 skills.
# Converted string skills to list at index 11392. Found 35 skills.
# Converted string skills to list at index 19475. Found 54 skills.
# Converted string skills to list at index 11975. Found 95 skills.
# Converted string skills to list at index 12144. Found 24 skills.
# Converted string skills to list at index 24380. Found 136 skills.
# Converted string skills to list at index 4903. Found 64 skills.
# Converted string skills to list at index 13327. Found 51 skills.
# Converted string skills to list at index 25436. Found 37 skills.
# Converted string skills to list at index 29205. Found 33 skills.
# Converted string skills to list at index 29115. Found 28 skills.
# Converted string skills to list at index 34169. Found 39 skills.
# Converted string skills to list at index 11815. Found 68 skills.
# Converted string skills to list at index 17875. Found 87 skills.
# Converted string skills to list at index 2658. Found 120 skills.
# Converted string skills to list at index 11177. Found 32 skills.
# Converted string skills to list at index 32675. Found 28 skills.
# Converted string skills to list at index 34247. Found 73 skills.
# Converted string skills to list at index 8240. Found 25 skills.
# Converted string skills to list at index 26447. Found 130 skills.
# Converted string skills to list at index 16907. Found 95 skills.
# Converted string skills to list at index 3195. Found 110 skills.
# Converted string skills to list at index 13795. Found 154 skills.
# Converted string skills to list at index 32843. Found 47 skills.
# Converted string skills to list at index 21362. Found 38 skills.
# Converted string skills to list at index 19065. Found 85 skills.
# Converted string skills to list at index 23350. Found 172 skills.
# Converted string skills to list at index 19288. Found 45 skills.
# Converted string skills to list at index 4398. Found 187 skills.
# Converted string skills to list at index 30357. Found 33 skills.
# Converted string skills to list at index 17073. Found 35 skills.
# Converted string skills to list at index 11559. Found 49 skills.
# Converted string skills to list at index 30174. Found 120 skills.
# Converted string skills to list at index 8091. Found 39 skills.
# Converted string skills to list at index 28626. Found 51 skills.
# Converted string skills to list at index 13832. Found 43 skills.
# Converted string skills to list at index 32024. Found 43 skills.
# Converted string skills to list at index 23735. Found 36 skills.
# Converted string skills to list at index 25008. Found 160 skills.
# Converted string skills to list at index 33124. Found 41 skills.
# Converted string skills to list at index 5583. Found 31 skills.
# Converted string skills to list at index 12105. Found 167 skills.
# Converted string skills to list at index 27377. Found 21 skills.
# Converted string skills to list at index 12592. Found 125 skills.
# Converted string skills to list at index 28546. Found 29 skills.
# Converted string skills to list at index 7476. Found 273 skills.
# Converted string skills to list at index 21328. Found 95 skills.
# Converted string skills to list at index 6308. Found 181 skills.
# Converted string skills to list at index 23685. Found 62 skills.
# Converted string skills to list at index 28532. Found 26 skills.
# Converted string skills to list at index 11943. Found 69 skills.
# Converted string skills to list at index 3503. Found 52 skills.
# Converted string skills to list at index 8727. Found 58 skills.
# Converted string skills to list at index 34394. Found 8 skills.
# Converted string skills to list at index 21050. Found 41 skills.
# Converted string skills to list at index 32206. Found 76 skills.
# Converted string skills to list at index 34424. Found 59 skills.
# Converted string skills to list at index 21547. Found 41 skills.
# Converted string skills to list at index 16245. Found 104 skills.
# Converted string skills to list at index 3120. Found 68 skills.
# Converted string skills to list at index 5723. Found 31 skills.
# Converted string skills to list at index 30151. Found 41 skills.
# Converted string skills to list at index 13717. Found 108 skills.
# Converted string skills to list at index 31743. Found 24 skills.
# Converted string skills to list at index 25257. Found 37 skills.
# Warning: skills_list is not iterable at index 34398. Value: nan. Using empty list.
# Converted string skills to list at index 13465. Found 143 skills.
# Converted string skills to list at index 33591. Found 20 skills.
# Converted string skills to list at index 11957. Found 28 skills.
# Converted string skills to list at index 25477. Found 30 skills.
# Converted string skills to list at index 2412. Found 30 skills.
# Converted string skills to list at index 28743. Found 44 skills.
# Converted string skills to list at index 27135. Found 67 skills.
# Converted string skills to list at index 32965. Found 58 skills.
# Converted string skills to list at index 34408. Found 135 skills.
# Converted string skills to list at index 20281. Found 43 skills.
# Converted string skills to list at index 34423. Found 67 skills.
# Converted string skills to list at index 34439. Found 139 skills.
# Converted string skills to list at index 30902. Found 36 skills.
# Converted string skills to list at index 23986. Found 46 skills.
# Converted string skills to list at index 1544. Found 76 skills.
# Converted string skills to list at index 1463. Found 63 skills.
# Converted string skills to list at index 31320. Found 34 skills.
# Converted string skills to list at index 11465. Found 51 skills.
# Processed 190 rows with 0 errors. Generated 190 valid examples.
# Training data: 759 examples
# Validation data: 190 examples
# Sample annotation: [{'start': 48, 'end': 52, 'label': 'MISC'}, {'start': 173, 'end': 177, 'label': 'MISC'}]

# %%
# Create label list from keyword_mappings
labels = ["O"]  # Start with "O" for non-entity tokens
for skill_type in keyword_mappings.keys():
    labels.append(f"B-{skill_type}")
    labels.append(f"I-{skill_type}")

# Add MISC for anything that doesn't match
labels.append("B-MISC")
labels.append("I-MISC")

# Create label mappings
label_to_id = {label: i for i, label in enumerate(labels)}
id_to_label = {i: label for i, label in enumerate(labels)}

print(f"Total labels: {len(labels)}")
print("Label examples:", labels[:10])
# Out:
# Total labels: 25
# Label examples: ['O', 'B-PL', 'I-PL', 'B-FW', 'I-FW', 'B-DB', 'I-DB', 'B-CP', 'I-CP', 'B-DO']

# %%
# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained("dslim/bert-base-NER")

# Convert to HF datasets
def convert_to_hf_dataset(data_list):
    texts = [item["text"] for item in data_list]
    dataset_dict = {"text": texts, "annotations": [item["annotations"] for item in data_list]}
    return Dataset.from_dict(dataset_dict)

train_dataset = convert_to_hf_dataset(train_data)
val_dataset = convert_to_hf_dataset(val_data)

print(f"Train dataset features: {train_dataset.features}")
print(f"Train dataset size: {len(train_dataset)}")
# Out:
# Train dataset features: {'text': Value(dtype='string', id=None), 'annotations': [{'end': Value(dtype='int64', id=None), 'label': Value(dtype='string', id=None), 'start': Value(dtype='int64', id=None)}]}
# Train dataset size: 759

# %%
# Tokenize and align labels function
def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(
        examples["text"], 
        truncation=True, 
        padding="max_length",
        max_length=256,
        return_offsets_mapping=True
    )
    
    labels = []
    for i, annotations in enumerate(examples["annotations"]):
        label_ids = [label_to_id["O"]] * len(tokenized_inputs["input_ids"][i])
        offset_mapping = tokenized_inputs["offset_mapping"][i]
        
        for annotation in annotations:
            start_char = annotation["start"]
            end_char = annotation["end"]
            label = annotation["label"]
            
            # Find tokens corresponding to this entity
            token_start_index = None
            token_end_index = None
            
            for j, (start, end) in enumerate(offset_mapping):
                if start == end:  # Skip special tokens
                    continue
                    
                if token_start_index is None and start <= start_char < end:
                    token_start_index = j
                    
                if end > 0 and start < end_char <= end:
                    token_end_index = j
            
            if token_start_index is not None and token_end_index is not None:
                # Assign B- label to first token
                label_ids[token_start_index] = label_to_id[f"B-{label}"]
                
                # Assign I- label to remaining tokens
                for j in range(token_start_index + 1, token_end_index + 1):
                    label_ids[j] = label_to_id[f"I-{label}"]
        
        # Set special tokens to -100
        for j, input_id in enumerate(tokenized_inputs["input_ids"][i]):
            if j == 0 or j == len(label_ids) - 1 or input_id == tokenizer.pad_token_id:
                label_ids[j] = -100
        
        labels.append(label_ids)
    
    # Remove offset_mapping from the features
    tokenized_inputs.pop("offset_mapping")
    tokenized_inputs["labels"] = labels
    
    return tokenized_inputs

# Apply tokenization to datasets
tokenized_train_dataset = train_dataset.map(tokenize_and_align_labels, batched=True)
tokenized_val_dataset = val_dataset.map(tokenize_and_align_labels, batched=True)

print(f"Tokenized train features: {tokenized_train_dataset.features}")
# Out:
# Map:   0%|          | 0/759 [00:00<?, ? examples/s]
# Map:   0%|          | 0/190 [00:00<?, ? examples/s]
# Tokenized train features: {'text': Value(dtype='string', id=None), 'annotations': [{'end': Value(dtype='int64', id=None), 'label': Value(dtype='string', id=None), 'start': Value(dtype='int64', id=None)}], 'input_ids': Sequence(feature=Value(dtype='int32', id=None), length=-1, id=None), 'token_type_ids': Sequence(feature=Value(dtype='int8', id=None), length=-1, id=None), 'attention_mask': Sequence(feature=Value(dtype='int8', id=None), length=-1, id=None), 'labels': Sequence(feature=Value(dtype='int64', id=None), length=-1, id=None)}

# %%
model = AutoModelForTokenClassification.from_pretrained(
    "dslim/bert-base-NER", 
    num_labels=len(labels),
    id2label=id_to_label,
    label2id=label_to_id,
    ignore_mismatched_sizes=True,
    hidden_dropout_prob=0.2,    # Slightly increase dropout
    attention_probs_dropout_prob=0.2
)
# Define metrics computation
def compute_metrics(pred):
    predictions, labels = pred
    predictions = predictions.argmax(axis=2)
    
    # Only use valid predictions (not -100)
    true_predictions = [
        [id_to_label[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    true_labels = [
        [id_to_label[l] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    
    # Flatten lists
    flat_predictions = [p for sublist in true_predictions for p in sublist]
    flat_labels = [l for sublist in true_labels for l in sublist]
    
    # Calculate metrics
    results = precision_recall_fscore_support(
        flat_labels,
        flat_predictions,
        average='weighted'
    )
    
    return {
        "precision": results[0],
        "recall": results[1],
        "f1": results[2]
    }
# Out:
# Some weights of the model checkpoint at dslim/bert-base-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at dslim/bert-base-NER and are newly initialized because the shapes did not match:
# - classifier.bias: found shape torch.Size([9]) in the checkpoint and torch.Size([25]) in the model instantiated
# - classifier.weight: found shape torch.Size([9, 768]) in the checkpoint and torch.Size([25, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Set up training arguments
training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    num_train_epochs=3,
    weight_decay=0.01,
    report_to="none"
)

# Initialize Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train_dataset,
    eval_dataset=tokenized_val_dataset,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)
# Out:
# c:\Users\User\anaconda3\Lib\site-packages\accelerate\accelerator.py:432: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches', 'even_batches', 'use_seedable_sampler']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False, even_batches=True, use_seedable_sampler=True)
#   warnings.warn(

# %%
# Train the model
trainer.train()

# Save the model
model.save_pretrained("./ner_skills_model")
tokenizer.save_pretrained("./ner_skills_model")

# Evaluate the model
eval_results = trainer.evaluate()
print(f"Evaluation results: {eval_results}")
# Out:
#   0%|          | 0/570 [00:00<?, ?it/s]
#   0%|          | 0/48 [00:00<?, ?it/s]
# c:\Users\User\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'eval_loss': 0.3299342393875122, 'eval_precision': 0.898746660627385, 'eval_recall': 0.8889237134081364, 'eval_f1': 0.8922536439055734, 'eval_runtime': 36.9364, 'eval_samples_per_second': 5.144, 'eval_steps_per_second': 1.3, 'epoch': 1.0}
#   0%|          | 0/48 [00:00<?, ?it/s]
# c:\Users\User\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'eval_loss': 0.28387945890426636, 'eval_precision': 0.9063697368999505, 'eval_recall': 0.9027560124532481, 'eval_f1': 0.9032618555675007, 'eval_runtime': 38.4388, 'eval_samples_per_second': 4.943, 'eval_steps_per_second': 1.249, 'epoch': 2.0}
# {'loss': 0.3769, 'grad_norm': 1.1018067598342896, 'learning_rate': 2.456140350877193e-06, 'epoch': 2.63}
#   0%|          | 0/48 [00:00<?, ?it/s]
# c:\Users\User\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'eval_loss': 0.28758832812309265, 'eval_precision': 0.9094298787654872, 'eval_recall': 0.9024843812031175, 'eval_f1': 0.9041541609906925, 'eval_runtime': 36.9727, 'eval_samples_per_second': 5.139, 'eval_steps_per_second': 1.298, 'epoch': 3.0}
# {'train_runtime': 1875.7932, 'train_samples_per_second': 1.214, 'train_steps_per_second': 0.304, 'train_loss': 0.36332988069768535, 'epoch': 3.0}
#   0%|          | 0/48 [00:00<?, ?it/s]
# Evaluation results: {'eval_loss': 0.28758832812309265, 'eval_precision': 0.9094298787654872, 'eval_recall': 0.9024843812031175, 'eval_f1': 0.9041541609906925, 'eval_runtime': 37.441, 'eval_samples_per_second': 5.075, 'eval_steps_per_second': 1.282, 'epoch': 3.0}
# c:\Users\User\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
